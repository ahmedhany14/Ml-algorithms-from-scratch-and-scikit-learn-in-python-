# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as nb
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split # used to split data set into (x, y) train and (x, y) test 
from sklearn.preprocessing import StandardScaler # used to transform data in to stadarization form
from sklearn.metrics import accuracy_score
df = pd.read_csv(r'/home/ahmed/Ai/Analysis/Data analysies/scikt learn/world_population.csv')
df
# Out:
# /tmp/ipykernel_13070/2875475870.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#      high_GPA  math_SAT  verb_SAT  comp_GPA  univ_GPA
# 0        3.45       643       589      3.76      3.52
# 1        2.78       558       512      2.87      2.91
# 2        2.52       583       503      2.54      2.40
# 3        3.67       685       602      3.83      3.47
# 4        3.24       592       538      3.29      3.47
# ..        ...       ...       ...       ...       ...
# 100      3.76       605       590      3.74      3.64
# 101      3.49       692       683      3.27      3.42
# ...

# %% [markdown]
# # spliting data to train and test

# %%
train, test = df[['high_GPA', 'math_SAT', 'verb_SAT', 'comp_GPA']], df['univ_GPA']
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size=.2,random_state=0)

# %% [markdown]
# # defining an object from LinearRegression, and then train the model

# %% [markdown]
# ### fit
# fit function used to train the model, taks 2 parametars (inputs, outputs)
#
#     x_train, y_train

# %%
lin_reg = LinearRegression()
lin_reg.fit(X=x_train,y=y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### predict
# predict function used to get predicted results from model, which taks 1 parametars (inputs)
#
#     x_test
#
# return output
#
#     predict of model

# %%
predict = lin_reg.predict(x_test)
print('The result of model is : ')
print(predict)
# Out:
# The result of model is :
# [2.6670713  3.26128004 2.66000098 3.50702704 3.33485598 2.96323318
#  3.77334275 3.67980707 3.25613839 3.05487138 3.41509667 3.19453615
#  2.44718411 3.50147375 2.2997549  3.4930815  3.15181731 3.6746806
#  3.78244039 2.89201887 3.17111883]

# %%
samples = len(x_test)
accual = list(y_test)
for i, j in zip(accual, predict):
    print('accual = ', i, '  --->     predict = ', j)
# Out:
# accual =  2.4   --->     predict =  2.6670712961991203
# accual =  3.38   --->     predict =  3.2612800398993236
# accual =  2.4   --->     predict =  2.6600009793211448
# accual =  3.41   --->     predict =  3.507027036961841
# accual =  3.48   --->     predict =  3.3348559817433405
# accual =  3.01   --->     predict =  2.963233182264533
# accual =  3.73   --->     predict =  3.773342753247192
# accual =  3.64   --->     predict =  3.679807071894379
# accual =  3.4   --->     predict =  3.2561383874030136
# accual =  3.19   --->     predict =  3.0548713772712426
# accual =  3.37   --->     predict =  3.4150966650163865
# accual =  3.28   --->     predict =  3.1945361478451404
# accual =  2.4   --->     predict =  2.447184105758595
# accual =  3.71   --->     predict =  3.5014737452673206
# accual =  2.24   --->     predict =  2.2997549017536816
# accual =  3.62   --->     predict =  3.4930815032246647
# accual =  3.28   --->     predict =  3.151817314385253
# ...

# %% [markdown]
# ### score
# score function used to compare the result of model output and accual output, which taks 1 parametars (inputs)
#
#     x_test, y_test
#
# return percentage
#
#     score of model

# %%
print('The socre of the model = ', lin_reg.score(X=x_test,y=y_test) * 100, '%')
# Out:
# The socre of the model =  91.49101142887582 %

# %% [markdown]
# # coefficients
# return the coefficients of the model fucntion
#
#     f_wb = w0*x0 + w1*x1 +w2*x2 + w3*x3 + b
#
# it will return
#
#     w0, w1, w2, w3

# %%
print(lin_reg.coef_)
# Out:
# [ 9.93006756e-02 -3.63995618e-04  4.48669211e-04  7.21372448e-01]
