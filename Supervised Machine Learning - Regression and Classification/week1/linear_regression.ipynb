# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as nb
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split # used to split data set into (x, y) train and (x, y) test 
from sklearn.preprocessing import StandardScaler # used to transform data in to stadarization form
from sklearn.metrics import accuracy_score
df = pd.read_csv(r'/home/ahmed/Ai/Analysis/Data analysies/scikt learn/world_population.csv')
df
# Out:
#      high_GPA  math_SAT  verb_SAT  comp_GPA  univ_GPA
# 0        3.45       643       589      3.76      3.52
# 1        2.78       558       512      2.87      2.91
# 2        2.52       583       503      2.54      2.40
# 3        3.67       685       602      3.83      3.47
# 4        3.24       592       538      3.29      3.47
# ..        ...       ...       ...       ...       ...
# 100      3.76       605       590      3.74      3.64
# 101      3.49       692       683      3.27      3.42
# 102      3.07       680       692      3.19      3.25
# 103      2.19       617       503      2.98      2.76
# 104      3.46       516       528      3.28      3.41
#
# [105 rows x 5 columns]

# %% [markdown]
# # spliting data to train and test

# %%
train, test = df[['high_GPA', 'math_SAT', 'verb_SAT', 'comp_GPA']], df['univ_GPA']
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size=.2,random_state=0)

# %% [markdown]
# # defining an object from LinearRegression, and then train the model

# %% [markdown]
# ### fit
# fit function used to train the model, taks 2 parametars (inputs, outputs)
#
#     x_train, y_train

# %%
lin_reg = LinearRegression()
lin_reg.fit(X=x_train,y=y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### predict
# predict function used to get predicted results from model, which taks 1 parametars (inputs)
#
#     x_test
#
# return output
#
#     predict of model

# %%
predict = lin_reg.predict(x_test)
print('The result of model is : ')
print(predict)
# Out:
# The result of model is :
# [2.87687329 3.27742331 2.79676329 3.31080248 3.30412664 3.25739581
#  3.72470416 3.62456665 3.21066497 2.72332912 3.46434665 3.24404414
#  3.01038997 3.42429165 2.68994995 3.49104998 2.75670829 3.52442915
#  3.78478666 2.73000496 3.00371413]

# %%
samples = len(x_test)
accual = list(y_test)
for i, j in zip(accual, predict):
    print('accual = ', i, '  --->     predict = ', j)
# Out:
# accual =  2.4   --->     predict =  2.8768732937346764
# accual =  3.38   --->     predict =  3.277423307656954
# accual =  2.4   --->     predict =  2.7967632909502207
# accual =  3.41   --->     predict =  3.31080247548381
# accual =  3.48   --->     predict =  3.3041266419184385
# accual =  3.01   --->     predict =  3.2573958069608397
# accual =  3.73   --->     predict =  3.72470415653683
# accual =  3.64   --->     predict =  3.624566653056261
# accual =  3.4   --->     predict =  3.210664972003241
# accual =  3.19   --->     predict =  2.723329121731137
# accual =  3.37   --->     predict =  3.46434664748735
# accual =  3.28   --->     predict =  3.244044139830097
# accual =  2.4   --->     predict =  3.010389965042102
# accual =  3.71   --->     predict =  3.424291646095122
# accual =  2.24   --->     predict =  2.68994995390428
# accual =  3.62   --->     predict =  3.491049981748835
# accual =  3.28   --->     predict =  2.756708289557993
# accual =  3.61   --->     predict =  3.5244291495756914
# accual =  3.76   --->     predict =  3.7847866586251717
# accual =  3.02   --->     predict =  2.7300049552965078
# accual =  3.39   --->     predict =  3.003714131476731

# %% [markdown]
# ### score
# score function used to compare the result of model output and accual output, which taks 1 parametars (inputs)
#
#     x_test, y_test
#
# return percentage
#
#     score of model

# %%
print('The socre of the model = ', lin_reg.score(X=x_test,y=y_test) * 100, '%')
# Out:
# The socre of the model =  57.26696397623816 %

# %% [markdown]
# # coefficients
# return the coefficients of the model fucntion
#
#     f_wb = w0*x0 + w1*x1 +w2*x2 + w3*x3 + b
#
# it will return
#
#     w0, w1, w2, w3

# %%
print(lin_reg.coef_)
# Out:
# [0.66758336]
